# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.remote.webelement import WebElement
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
from functions import *
from time import sleep
from datetime import datetime
import sys
import os
import math
import unicodedata
import pandas as pd
from pprint import pprint

# %%
url = 'https://digital.stf.jus.br/publico/publicacoes'

# %%
options = webdriver.ChromeOptions()
options.add_argument('--log-level=3')
# options.add_argument('--no-sandbox')
# options.add_argument('--disable-dev-shm-usage')

# Criando objeto chrome sem precisar ficar baixando a versão atualizada do chromedriver
chrome = webdriver.Chrome(
    options=options,
    service=ChromeService(ChromeDriverManager().install())
    )
chrome.get(url)

sleep(10)

# %%
elementos = chrome.find_elements(By.CLASS_NAME, 'publicacoes')

# %%
for elem in elementos:
    # Pegar número do processo
    processo = elem.find_element(By.CLASS_NAME, 'processo')
    text_processo = outer_html(processo)
    print(f'<P> {text_processo}')

    relator = elem.find_element(By.CLASS_NAME, 'relator')
    text_relator = outer_html(relator)
    
    envolvidos = elem.find_element(
                        By.CLASS_NAME, 'layout-align-space-between-start'
                        )
    envolvidos = envolvidos.find_elements(By.CLASS_NAME, 'envolvido')
    for envolvido in envolvidos:
        text_envolvido = outer_html(envolvido)
        pprint(text_envolvido)
    
    shadow_section = elem.find_element(By.CLASS_NAME, 'shadow')
    shadow_root_dict = chrome.execute_script(
        "return arguments[0].shadowRoot", shadow_section
        )
    
    shadow_root_id = shadow_root_dict['shadow-6066-11e4-a52e-4f735466cecf']
    shadow_root = WebElement(chrome, shadow_root_id, w3c=True)

    try:
        decisao = shadow_root.find_element(
                        By.CLASS_NAME, 'P1'
                        )
        texto_decisao = outer_html(decisao)
        print(texto_decisao)
    except:
        pass

    content_html = shadow_root.find_elements(
                        By.TAG_NAME, 'p'
                        )
    
    for conteudo in content_html:
        # Desvio para corrigir problema de não carregar o HTML
        texto = outer_html(conteudo)

        if texto == texto_decisao:
            continue
    
        print(texto)
# Out:
# <P> ADPF 902 ADPF-ED
# 'EMBARGANTE(S) Governador do Estado do Rio de Janeiro '
# 'PROCURADOR(ES) Procurador-geral do Estado do Rio de Janeiro '
# 'EMBARGADO(A/S) Tribunal Regional do Trabalho da 1ª Região '
# 'ADVOGADO(A/S) Sem Representação nos Autos '
#
# Decisão: O Tribunal, por unanimidade, rejeitou os embargos de declaração, nos termos do voto do Relator. Plenário, Sessão Virtual de 3.3.2023 a 10.3.2023.
#
#
#
# <P> ADPF 902 ADPF-ED
# 'EMBARGANTE(S) Governador do Estado do Rio de Janeiro '
# 'PROCURADOR(ES) Procurador-geral do Estado do Rio de Janeiro '
# 'EMBARGADO(A/S) Tribunal Regional do Trabalho da 1ª Região '
# 'ADVOGADO(A/S) Sem Representação nos Autos '
#
# Decisão: O Tribunal, por unanimidade, rejeitou os embargos de declaração, nos termos do voto do Relator. Plenário, Sessão Virtual de 3.3.2023 a 10.3.2023.
#
#
#
# <P> ADPF 964 Mérito
# 'REQUERENTE(S) Rede Sustentabilidade '
# "ADVOGADO(A/S) Flavia Calado Pereira |OAB's (24842-A/MA, 3864/AP)"
# 'INTERESSADO(A/S)  Presidente da República '
# 'PROCURADOR(ES) Advogado-geral da União '
#
#    DIREITO PENAL
#
# Parte Geral
# Extinção da Punibilidade
# Perdão
#
#
# <P> ADPF 965 Mérito
# 'REQUERENTE(S) Partido Democratico Trabalhista '
# 'ADVOGADO(A/S) Walber de Moura Agra |OAB 00757/PE'
# 'ADVOGADO(A/S) Mara de Fatima Hofans |OAB 068152/RJ'
# 'ADVOGADO(A/S) Ian Rodrigues Dias |OAB 10074/DF'
# "ADVOGADO(A/S) Marcos Ribeiro de Ribeiro |OAB's (062818/RJ, 62589/DF)"
# 'INTERESSADO(A/S)  Presidente da República '
# 'PROCURADOR(ES) Advogado-geral da União '
#
#    DIREITO PENAL
#
# Parte Geral
# Extinção da Punibilidade
# Perdão
#
#
# <P> ADPF 966 Mérito
# 'REQUERENTE(S) Cidadania '
# 'ADVOGADO(A/S) Paulo Roberto Iotti Vecchiatti e Outro(a/s) |OAB 242668/SP'
# 'ADVOGADO(A/S) RENATO CAMPOS GALUPPO |OAB 90819 /MG'
# 'INTERESSADO(A/S)  Presidente da República '
# 'PROCURADOR(ES) Advogado-geral da União '
#
#    DIREITO PENAL
#
# Parte Geral
# Extinção da Punibilidade
# Perdão
#
#
# <P> ADPF 967 Mérito
# 'REQUERENTE(S) Partido Socialismo e Liberdade (p-sol) '
# "ADVOGADO(A/S) Walfrido Jorge Warde Junior |OAB's (69684/DF, 139503/SP)"
# "ADVOGADO(A/S) Pedro Estevam Alves Pinto Serrano |OAB's (90846/SP, 19586/DF)"
# "ADVOGADO(A/S) Rafael Ramires Araujo Valim |OAB's (70786/DF, 248606/SP)"
# "ADVOGADO(A/S) Gustavo Marinho de Carvalho |OAB's (71875/DF, 246900/SP)"
# 'INTERESSADO(A/S)  Presidente da República '
# 'PROCURADOR(ES) Advogado-geral da União '
#
#    DIREITO PENAL
#
# Parte Geral
# Extinção da Punibilidade
# Perdão
#
#
# <P> ADPF 986 ADPF-ED
# 'EMBARGANTE(S) Instituto Brasileiro de Defesa do Consumidor - Idec '
# "ADVOGADO(A/S) Igor Rodrigues Britto e Outro(a/s) |OAB's (18461/ES, 54565/DF)"
# 'ADVOGADO(A/S) ANA CAROLINA NAVARRETE MUNHOZ FERNANDES DA CUNHA |OAB 310337/SP'
# 'ADVOGADO(A/S) Christian Tarik Printes |OAB 316680/SP'
# 'EMBARGADO(A/S) Agência Nacional de Saúde Suplementar '
# 'PROCURADOR(ES) Procurador-geral Federal |OAB 00000/DF'
# 'INTERESSADO(A/S) Rede Sustentabilidade e Outro(a/s) '
# 'EMBARGANTE(S) INSTITUTO BRASILEIRO DE DEFESA DO CONSUMIDOR (“IDEC”) '
# 'ADVOGADO(A/S) Walter Jose Faiad de Moura |OAB 17390/DF'
# 'ADVOGADO(A/S) Christian Tarik Printes |OAB 316680/SP'
# 'ADVOGADO(A/S) Rayssa Carvalho da Silva |OAB 2325/AP'
#
# Decisão: O Tribunal, por maioria, rejeitou os embargos de declaração, nos termos do voto do Relator, vencidos os Ministros Edson Fachin, Ricardo Lewandowski, Dias Toffoli e Rosa Weber (Presidente). Plenário, Sessão Virtual de 3.3.2023 a 10.3.2023.
#
#
#
# <P> ADPF 986 ADPF-ED
# 'EMBARGANTE(S) Instituto Brasileiro de Defesa do Consumidor - Idec '
# "ADVOGADO(A/S) Igor Rodrigues Britto e Outro(a/s) |OAB's (18461/ES, 54565/DF)"
# 'ADVOGADO(A/S) ANA CAROLINA NAVARRETE MUNHOZ FERNANDES DA CUNHA |OAB 310337/SP'
# 'ADVOGADO(A/S) Christian Tarik Printes |OAB 316680/SP'
# 'EMBARGADO(A/S) Agência Nacional de Saúde Suplementar '
# 'PROCURADOR(ES) Procurador-geral Federal |OAB 00000/DF'
# 'INTERESSADO(A/S) Rede Sustentabilidade e Outro(a/s) '
# 'EMBARGANTE(S) INSTITUTO BRASILEIRO DE DEFESA DO CONSUMIDOR (“IDEC”) '
# 'ADVOGADO(A/S) Walter Jose Faiad de Moura |OAB 17390/DF'
# 'ADVOGADO(A/S) Christian Tarik Printes |OAB 316680/SP'
# 'ADVOGADO(A/S) Rayssa Carvalho da Silva |OAB 2325/AP'
#
# Decisão: O Tribunal, por maioria, rejeitou os embargos de declaração, nos termos do voto do Relator, vencidos os Ministros Edson Fachin, Ricardo Lewandowski, Dias Toffoli e Rosa Weber (Presidente). Plenário, Sessão Virtual de 3.3.2023 a 10.3.2023.
#
#
#
# <P> AI 868630
# 'AGRAVANTE(S) Hsbc Asset Finance (brasil) Arrendamento Mercantil S/a '
# 'ADVOGADO(A/S) Gilberto Antonio de Miranda |OAB 43896 /MG'
# 'RECORRENTE(S) Finaustria Arrendamento Mercantil S/a '
# 'ADVOGADO(A/S) Alzira Maria Rohrmann Ferreira |OAB 42880 /MG'
# 'AGRAVANTE(S) Citibank Leasing S a Arrendamento Mercantil '
# 'AGRAVADO(A/S) Movimento das Donas de Casa e Consumidores de Minas Ger '
# 'ADVOGADO(A/S) Delio de Jesus Malheiros |OAB 54413 /MG'
# 'INTERESSADO(A/S) Gm Leasing 5/a Arrendamento Mercantil e Outro(a/s) '
# 'INTERESSADO(A/S) FORD LEASING 5/A ARRENDAMENTO MERCANTIL '
# 'INTERESSADO(A/S) FIAT LEASING S/A ARRENDAMENTO MERCANTIL '
# "ADVOGADO(A/S) Lucila de Oliveira Carvalho |OAB's (43158 /MG, 411095/SP)"
# 'INTERESSADO(A/S) Unibanco Leasing S.a. Arrendamento Mercantil e Outro(a/s) '
# DESPACHO: Trata-se de três recursos extraordinários com agravo interpostos por CITIBANK LEASING S A ARRENDAMENTO MERCANTIL, por FINAUSTRIA ARRENDAMENTO MERCANTIL S/A e por HSBC ASSET FINANCE (BRASIL) ARRENDAMENTO MERCANTIL S/A contra decisão de inadmissão dos recursos interpostos contra o acórdão proferido pelo TRIBUNAL DE JUSTIÇA DO ESTADO DE MINAS GERAIS.
# Analisados os autos, verifica-se que inexistem óbices jurídicos que justifiquem a atuação da Presidência neste feito (art. 13, inciso V, alínea c, do Regimento Interno do Supremo Tribunal Federal).
# Ante o exposto, determino a distribuição do processo conforme expresso no regimento.
# Publique-se.
# Brasília, 23 de março de 2023.
#
# Ministra ROSA WEBER
# Presidente
# Documento assinado digitalmente
# <P> AO 1014 Mérito
# 'AUTOR(A/S)(ES) Walter Raimundo Spies '
# 'ADVOGADO(A/S) Decio Gianelli Rodrigues Martins |OAB 19556/RS'
# ('LITISCONSORTE(S) ATIVO(A/S) Associação dos Magistardos do Trabalho da 4º '
#  'Região - Amatra ')
# 'ADVOGADO(A/S) Sergio Jose Porto |OAB 5668/RS'
# 'RÉU(É)(S) União '
# 'PROCURADOR(ES) Advogado-geral da União '
#
# Decisão: Após os votos dos Ministros Marco Aurélio, Relator, e Alexandre de Moraes, que julgavam improcedente o pedido do autor, pediu vista do processo o Ministro Luiz Fux, Presidente. Não participou, justificadamente, deste julgamento, a Ministra Rosa Weber. Primeira Turma, 26.11.2019.
#
#
# Decisão: A Turma, por unanimidade, julgou improcedente o pedido formulado na inicial e condenou os autores ao pagamento das custas processuais e honorários advocatícios em favor da União, que, a teor do artigo 20 do Código de Processo Civil de 1973, ficam arbitrados em R$ 5.000,00, nos termos do voto do Relator. Redigirá o acórdão o Ministro Luiz Fux (Art. 38, IV, b, do RISTF). Não votou a Ministra Cármen Lúcia, sucessora do Ministro Marco Aurélio. Primeira Turma, Sessão Virtual de 3.3.2023 a 10.3.2023.
#
# Ementa: AÇÃO ORIGINÁRIA. MAGISTRADOS DO TRABALHO. PRETENSÃO À PERCEPÇÃO DE DIFERENÇAS DE VENCIMENTOS, DESDE FEVEREIRO DE 1995, DECORRENTES DE ALTERAÇÃO DA PARCELA AUTÔNOMA DE EQUIVALÊNCIA NO MESMO PATAMAR DE REAJUSTE IMPLEMENTADO QUANTO A MINISTROS DO STF. ALEGAÇÃO DE VIOLAÇÃO AO PRINCÍPIO DA ISONOMIA. SUSPENSÃO DE ATO ADMINISTRATIVO FORMALIZADO PELO TST OCORRIDA NA ADI 1.899. LEI Nº 8.448/1992. EQUIVALÊNCIA ENTRE VALORES PAGOS A MEMBROS DO CONGRESSO NACIONAL, MINISTROS DE ESTADO E MINISTROS DO STF. ART. 93, V, DA CONSTITUIÇÃO FEDERAL. LIMITE MÁXIMO REFERENTE AO ESCALONAMENTO DE CATEGORIA. PEDIDO JULGADO IMPROCEDENTE, FIXADOS HONORÁRIOS ADVOCATÍCIOS, NOS TERMOS DO VOTO DO MIN. RELATOR.
