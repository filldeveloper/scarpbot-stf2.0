# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.remote.webelement import WebElement
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
from functions import *
from time import sleep
from datetime import datetime
import sys
import os
import math
import unicodedata
import pandas as pd
from pprint import pprint

# %%
url = 'https://digital.stf.jus.br/publico/publicacoes'

# %%
options = webdriver.ChromeOptions()
options.add_argument('--log-level=3')
# options.add_argument('--no-sandbox')
# options.add_argument('--disable-dev-shm-usage')

# Criando objeto chrome sem precisar ficar baixando a versão atualizada do chromedriver
chrome = webdriver.Chrome(
    options=options,
    service=ChromeService(ChromeDriverManager().install())
    )
chrome.get(url)

sleep(10)

# %%
elementos = chrome.find_elements(By.CLASS_NAME, 'publicacoes')

# %%
for elem in elementos:
    # Pegar número do processo
    processo = elem.find_element(By.CLASS_NAME, 'processo')
    text_processo = outer_html(processo)
    print(f'<P> {text_processo}')

    relator = elem.find_element(By.CLASS_NAME, 'relator')
    text_relator = outer_html(relator)
    
    envolvidos = elem.find_element(
                        By.CLASS_NAME, 'layout-align-space-between-start'
                        )
    envolvidos = envolvidos.find_elements(By.CLASS_NAME, 'envolvido')
    for envolvido in envolvidos:
        text_envolvido = outer_html(envolvido)
        pprint(text_envolvido)
    
    shadow_section = elem.find_element(By.CLASS_NAME, 'shadow')
    shadow_root_dict = chrome.execute_script(
        "return arguments[0].shadowRoot", shadow_section
        )
    
    shadow_root_id = shadow_root_dict['shadow-6066-11e4-a52e-4f735466cecf']
    shadow_root = WebElement(chrome, shadow_root_id, w3c=True)

    try:
        decisao = shadow_root.find_element(
                        By.CLASS_NAME, 'P1'
                        )
        texto_decisao = outer_html(decisao)
        print(texto_decisao)
    except:
        pass

    content_html = shadow_root.find_elements(
                        By.TAG_NAME, 'p'
                        )
    
    for conteudo in content_html:
        # Desvio para corrigir problema de não carregar o HTML
        texto = outer_html(conteudo)

        if texto == texto_decisao:
            continue
    
        print(texto)
# Out:
# <P> ACO 2994
# 'AUTOR(A/S)(ES) Estado do Rio de Janeiro '
# 'PROCURADOR(ES) Procurador-geral do Estado do Rio de Janeiro '
# 'RÉU(É)(S) União '
# 'PROCURADOR(ES) Advogado-geral da União '
# 'RÉU(É)(S) Agência Nacional do Petróleo - Anp '
# 'PROCURADOR(ES) Procurador-geral Federal |OAB 00000/DF'
# 'INTERESSADO(A/S) Confederação Nacional de Municípios '
# 'ADVOGADO(A/S) Paulo Antônio Caliendo Velloso da Silveira |OAB 33940/RS'
# DESPACHO
#
# 1. Trata-se de ação cível originária ajuizada pelo Estado do Rio de Janeiro em face da União e da Agência Nacional do Petróleo, Gás Natural e Biocombustíveis (ANP), visando à restituição dos valores relativos à remuneração incidente sobre os saldos de royalties e de participação especial decorrentes da exploração do petróleo e do gás natural, no período em que esses recursos permanecem depositados na conta do Tesouro Nacional.
#
# 2. O Estado autor alega que os royalties são depositados pelas empresas exploradoras desses recursos naturais diretamente na conta do Tesouro Nacional. Posteriormente, parcela dessa receita é repassada aos Estados e Municípios produtores, em cumprimento ao art. 20, § 1º, da Constituição da República.
#
# 3. Sustenta que, durante o intervalo de tempo em que permanecem na conta do Tesouro Nacional – antes, portanto, de serem repassados aos demais entes federados –, os recursos recebem correção pela Taxa Selic, nos termos da Lei nº 7.862, de 1989.
#
# 4. Aponta que a União repassa aos Estados-membros e Municípios destinatários apenas o valor principal, retendo a remuneração obtida no período em que os recursos estiveram na conta do Tesouro Nacional.
#
# 5. Argumenta que essa remuneração, a título de juros, passa a integrar o seu conteúdo, pois tem por finalidade preservar o valor real da quantia contra os efeitos da inflação, possuindo a mesma natureza jurídica dos royalties, isso é, de receita originária, de forma que a retenção pela União configura enriquecimento sem causa.
#
# 6. Requer que seja declarado o direito do Estado do Rio de Janeiro de receber os valores de royalties e participação especial com correção monetária, computada no período de tempo decorrido entre o recebimento dos royalties e participações especiais pelas rés e o efetivo repasse ao Estado autor. Requer, também, a condenação das rés, para que:
#
# “(i) passem a realizar os repasses dos royalties, mês a mês, no valor atualizado pela correção monetária;
# (ii) devolvam os valores atrasados de correção monetária não repassados, devidamente atualizados, nos últimos 5 (cinco) anos na forma prevista no Decreto nº 20.910, de 1932; e
# (iii) paguem os juros legais sobre as diferenças não pagas, computados da data de cada repasse efetuado sem a devida correção monetária.”
#
#
# 7. Pede, ainda, que a correção monetária seja feita com base na Taxa Selic do mês de referência, somando-se ao valor a atualização do percentual do INPC e, posteriormente, aplicando-se juros de 6% ao ano.
#
# 8. O pedido de liminar foi deferido “para determinar que as transferências dos depósitos referentes aos royalties e participações especiais devidos ao Estado do Rio de Janeiro sejam realizadas, a partir da publicação desta decisão, na completude, isto é, incluída a atualização referida pelo Banco Central a título de correção monetária” (e-doc. 40).
#
# 9. A União interpôs agravo regimental (e-doc. 59), no qual suscita a ausência de citação para apresentar contestação e especificar as provas que pretende produzir. Sustenta a inexistência de fumus boni iuris e a presença de periculum in mora inverso, ante a possibilidade de multiplicação da concessão de liminares em ações da mesma natureza.
#
# 10. Segundo alega, há uma “multiplicidade de processos, nos mais diversos graus de jurisdição”, nos quais também se discute a correção monetária de royalties e participações especiais, motivo pelo qual existe o risco de a concessão de medidas liminares semelhantes à presente ocasionar grave e imediato prejuízo às contas públicas.
#
# 11. A ANP apresentou contestação, na qual suscita, preliminarmente, sua ilegitimidade passiva. No mérito, alega inexistência de legislação aplicando correção monetária e juros sobre os mencionados depósitos, ausência de mora e enriquecimento sem causa pela Agência, bem como falta de previsão de incidência de remuneração pelo Banco Central apenas sobre as disponibilidades da União.
#
# 12. A ANP também interpôs agravo regimental (e-doc. 62) em face da decisão pela qual foi deferida a medida liminar pleiteada pelo autor. Suscita a ilegitimidade passiva para o feito, porquanto sua conduta se limita à elaboração dos cálculos para distribuição dos royalties a cada ente, cujo montante é constituído das quantias depositadas pelas empresas concessionárias, não tendo ingerência sobre o pagamento da correção monetária relativa aos dias em que os recursos ficam depositados na Conta Única do Tesouro Nacional.
#
# 13. A Confederação Nacional dos Municípios (CNM) requereu (e-doc. 71) a habilitação como amicus curiae, com fundamento nos arts. 138 do Código de Processo Civil e 21, inc. XVIII, do Regimento Interno do Supremo Tribunal Federal.
#
# 14. O e. Ministro Marco Aurélio, Relator originário do feito, admitiu (e-doc. 78) a CNM como terceira interessada, determinando (e-doc. 81), na sequência, a citação da União.
#
# 15. A União apresentou contestação (e-doc. 85), suscitando sua ilegitimidade passiva, sob o fundamento de que o Decreto nº 2.705, de 1998, retirou da Secretaria do Tesouro Nacional a competência para a distribuição das participações governamentais, passando-a à ANP. Quanto ao mérito, sustenta que a Lei nº 9.478, de 1997, que dispõe sobre o procedimento e os prazos de pagamento dos royalties de petróleo e gás natural, não prevê a aplicação de qualquer critério de correção monetária ou de incidência de juros para a distribuição dessa compensação financeira aos beneficiários.
#
# 16. Alega que a Medida Provisória nº 2.179-36, de 2001, prevê remuneração apenas sobre as disponibilidades da União. Argumenta a inexistência de previsão expressa de data para efetuar o repasse dos royalties, razão pela qual descabe falar em mora ou em pagamento extemporâneo da União a ensejar correção monetária dos valores. Defende que os royalties pagos pelos concessionários ficam depositados na Conta Única do Tesouro Nacional até a finalização do cálculo pela ANP da parcela devida a cada um dos entes beneficiários, de modo que eles não possuem direitos sobre a coisa com os seus melhoramentos e acrescidos até o efetivo repasse dos valores, que é quando se opera a transmissão da propriedade.
#
# 17. Argumenta que, desde a extinção do BTN (Bônus do Tesouro Nacional), índice de correção monetária previsto na Lei nº 7.990, de 1989, inexiste lei ou ato normativo atribuindo novo índice, razão pela qual não seria legítima a pretensão do autor em requerer a atualização pela Selic.
#
# 18. O autor ofereceu contrarrazões aos agravos regimentais e réplica às contestações.
#
# 19. A Procuradoria-Geral da República ofereceu manifestação:
#
# “(i) pela extinção do feito, sem resolução do mérito, em relação à Agência Nacional de Petróleo, nos termos do art. 485, VI, do Código de Processo Civil;
# (ii) pela intimação das partes para que apresentem manifestação sobre o interesse em conciliar submetendo o feito à Câmara de Conciliação e Arbitragem da Administração Federal (CCAF);
# (iii) caso não se vislumbre a possibilidade de conciliação, pela procedência parcial do pedido formulado na inicial para que incida a correção apenas sobre os valores a título de royalties por exploração de petróleo e gás natural distribuídos pela ré União após o último dia do mês subsequente ao do pagamento pelas concessionárias, por analogia ao art. 4º, § 2º, da LC 62/1989 c/c o ar. 18 do Decreto 2.705/1998, prejudicado o agravo interno interposto pela União.” (e-doc. 109).
#
# É o relatório, de momento.
#
# 20. Acolho o item ii da manifestação da Procuradoria-Geral da República, para determinar a intimação das partes para que se manifestem, no prazo de 10 (dez) dias, sobre eventual interesse em participar de processo conciliatório junto à Câmara de Mediação e de Conciliação da Administração Pública Federal (CCAF) ou neste Supremo Tribunal Federal.
#
# Publique-se.
#
# Brasília, 26 de março de 2023.
#
#
# Ministro ANDRÉ MENDONÇA
# Relator
# <P> ACO 3127 ACO-AgR-ED
# 'EMBARGANTE(S) União '
# 'PROCURADOR(ES) Advogado-geral da União '
# 'EMBARGADO(A/S) Empresa de Saneamento de Mato Grosso do Sul S.a.sanesul '
# 'ADVOGADO(A/S) Ana Karina de Oliveira e Silva e Outro(a/s) |OAB 10733/MS'
# 'ADVOGADO(A/S) LUCIANA DO CARMO RONDON |OAB 13204/MS'
# 'ADVOGADO(A/S) EDER ALVES DOS SANTOS |OAB 13147/MS'
# 'ADVOGADO(A/S) ROBSON MOTIZUKI |OAB 9635/MS'
#
# Decisão: A Turma, por unanimidade, negou provimento aos embargos de declaração, nos termos do voto do Relator. Primeira Turma, Sessão Virtual de 10.3.2023 a 17.3.2023.
#
#
# EMENTA: EMBARGOS DE DECLARAÇÃO NO AGRAVO INTERNO NA AÇÃO CÍVEL ORIGINÁRIA. IMUNIDADE DE SOCIEDADE DE ECONOMIA MISTA ESTADUAL EM FACE DE TRIBUTOS FEDERAIS. CONFLITO FEDERATIVO CONFIGURADO. IMPOSSIBILIDADE DE DISCUSSÃO DE ANULAÇÃO DE CRÉDITOS TRIBUTÁRIOS E REPETIÇÃO DE INDÉBITO. DISCUSSÕES MERAMENTE PATRIMONIAIS. ADITAMENTO À INICIAL. NOVO VALOR ATRIBUÍDO À CAUSA. CONGRUÊNCIA COM O PROVEITO ECONÔMICO PRETENDIDO. CONTRADIÇÃO. INEXISTÊNCIA. EFEITOS INFRINGENTES. IMPOSSIBILIDADE. PRECEDENTES. EMBARGOS DE DECLARAÇÃO DESPROVIDOS.
#
#
# <P> ACO 3205
# 'AUTOR(A/S)(ES) Estado do Piauí '
# 'PROCURADOR(ES) Procurador-geral do Estado do Piauí '
# 'RÉU(É)(S) União '
# 'PROCURADOR(ES) Advogado-geral da União '
# Decisão: Trata-se de ação cível originária, com pedido de tutela provisória de urgência, ajuizada pelo Estado do Piauí em face da União com vistas a impedir que esta proceda a inclusão daquele no cadastro de devedores da União (CAUC/SIAFI), sob o fundamento de aprovação parcial das contas do Convênio nº 29/2005 firmado entre o Ministério da Integração Nacional e a Secretaria de Infraestrutura do Estado do Piauí, tendo por objeto a elaboração de projetos para a construção da barragem de Castelo no município de Juazeiro do Piauí.
# Sustenta-se que a pessoa política Autora não pode sofrer sanções financeiras, como restrição de operações de crédito, avais ou transferências voluntárias, porque a reprovação das contas em questão foi motivada por responsabilidade solidária de dois ex-gestores. Evoca-se, portanto, o princípio da intranscendência subjetiva das sanções.
# Ademais, discorre acerca da necessidade de instauração de tomada de contas especial para apuração da responsabilidade dos ex-gestores previamente à anotação de inadimplência do ente público. Nesse sentido, assevera que “em que pese tenha atribuído responsabilidade expressa a ex-gestores, a Ré não se desincumbiu de instaurar a competente Tomada de Contas Especial, incorrendo, portanto, em manifesta violação devido processo legal estabelecido na Lei Federal nº 10.522/2002, que exige a adoção do referido procedimento previamente à inscrição do Ente Público em cadastros restritivos administrados pela União Federal.”
# Ao fim, requer que a parte ré se abstenha de promover a inscrição do Estado do Piauí em cadastros federais de inadimplência em decorrência da reprovação parcial das contas alusivas ao Convênio nº 29/2005 (SIAFI 531006).
# Foi deferida a tutela provisória pleiteada, com a finalidade de que fosse suspensa, até o julgamento definitivo desta demanda, a inscrição do Estado em cadastro restritivo federal com base no Convênio em questão (SIAFI 531006), assim como que a Ré abstivesse de promover novas medidas constritivas ao Autor em decorrência da reprovação parcial das contas referentes ao ajustamento em tela (eDOC 10).
# Em contestação, a União aponta a perda superveniente do interesse processual do autor. Alega, com base em informações prestadas pela Coordenação-Geral de Prestação de Contas de Convênios do Ministério do Desenvolvimento Regional, por meio da Nota Técnica nº 008/2019/Diad/CDTCE/CGPC/SPO/Secex/MDR, que “o Convênio nº 029/2005 (Siafi nº 531006) está com a situação de ‘Inadimplência Suspensa’ no Siafi, conforme espelho anexo, não havendo possibilidade de voltar a permanecer em Inadimplência efetiva, salvo se houverem fatos novos que resultem na responsabilização do Ente Convenente ou da pessoa de sua atual gestão, o que afastaria a possibilidade de aplicação do entendimento contido no §2º do art. 5º da IN/STN nº 1/1997”. (eDOC 19, p. 5)
# Discorre acerca da inaplicabilidade do princípio da intranscendência subjetiva das sanções, buscando demonstrar que “a simples mudança do mandatário local não tem o condão de fazer cessar as restrições legais e administrativas ao repasse de recursos federais. Cumpre à atual administração demonstrar a adoção das medidas legais cabíveis de apuração de responsabilidades.” (eDOC 19, p. 8-9).
# Por fim, articula com a desnecessidade de a inscrição no SIAFI ser precedida de tomada de contas especial em razão da ausência de respaldo legal e da própria lógica estabelecida no SIAFI/Subsistema Transferências.
# Instada a se manifestar, a parte autora se opôs ao pedido de extinção do feito sem resolução de mérito em razão de perda superveniente de objeto sob alegação de efetiva inscrição do Estado no Serviço Auxiliar de Informações para Transferências Voluntárias – CAUC/SIAFI (eDOC 30).
# Consignada a desnecessidade de produção de novas provas, determinei a intimação das parte para apresentação de alegações finais, bem como a abertura de vista dos autos ao Procurador-Geral da República (eDOC 32).
# O Estado do Piauí ratificou os termos da fundamentação constante na exordial (eDOC 33).
# A União, por sua vez, reiterou argumentação quanto à perda superveniente do objeto da presente ação, bem como requereu que “eventual ordem judicial definitiva tenha como baliza o decidido no RE nº 1.067.086-RG (Tema nº 327), limitando a tutela judicial inibitória ao julgamento de tomada de contas especial ou procedimento análogo perante o Tribunal de Contas da União.” (eDOC 36, p. 6)
# A Procuradoria-Geral da República ofertou parecer pela procedência do pedido, nos seguintes termos (eDOC 40, p. 1-2):
#
# “AÇÃO CÍVEL ORIGINÁRIA. CONSTITUCIONAL. ADMINISTRATIVO. FINANCEIRO. INSCRIÇÃO EM CADASTRO FEDERAL DE INADIMPLENTES. CAUC/SIAFI. IRREGULARIDADES NA PRESTAÇÃO DE CONTAS DO CONVÊNIO. TOMADA DE CONTAS ESPECIAL. INSTAURAÇÃO PRÉVIA. NECESSIDADE. PRINCÍPIO DO DEVIDO PROCESSO LEGAL. TEMA 327 DE REPERCUSSÃO GERAL. PRINCÍPIO DA INTRANSCENDÊNCIA DAS SANÇÕES. VIOLAÇÃO. OCORRÊNCIA. PROCEDÊNCIA DA AÇÃO. 1. Ação cível originária, proposta com fundamento no art. 102, I, f, da Constituição Federal, que objetiva cancelar a inscrição do Autor nos sistemas CAUC/SIAFI e possibilitar a contratação de operações de crédito e a transferência de recursos federais. 2. Há de ser reconhecida a competência do Supremo Tribunal Federal (STF) para, no exercício da sua atribuição de Tribunal da Federação, conhecer e julgar a ação, na forma do art. 102, I, f, da Constituição Federal, dada a potencial tensão entre as esferas federal e estadual de governo, apta a gerar desequilíbrios no particular modelo constitucional brasileiro de federalismo. 3. Segundo entendimento fixado pelo Supremo Tribunal Federal no julgamento do RE 1.067.086 (Tema 327 da Repercussão Geral), a inscrição dos entes federados em cadastros de inadimplente pressupõe o respeito aos princípios do contraditório, da ampla defesa e do devido processo legal, somente reconhecido após o julgamento de tomada de contas especial ou procedimento análogo perante o Tribunal de Contas nos casos de descumprimento parcial ou total de convênio, prestação de contas rejeitada ou existência de débito decorrente de ressarcimento de recursos de natureza contratual (salvo os de conta não prestada). 4. Admite-se a não responsabilização do gestor atual quando e se ele comprovar ter adotado as providências necessárias para a responsabilização dos agentes públicos antecessores que cometeram as irregularidades constatadas, o que não ocorreu no presente caso. - Parecer pela procedência da ação.”
#
# É o relatório. Decido.
# Assiste parcial razão à parte autora.
# Inicialmente, permanece hígida a decisão pretérita no tocante a competência do STF para processar e julgar a presente ação. Nesse sentido, reitero que é iterativa a compreensão deste Tribunal no sentido de que a inscrição de Estado-membro nos cadastros federais de inadimplência enquadram-se no preceito de conflito federativo presente na alínea “f” do inciso I do Texto Constitucional.
# Em sede de preliminar de mérito, verifico a persistência do interesse de agir da parte autora. Nesse sentido, a argumentação da União no tocante à suspensão não definitiva da condição de inadimplência referente ao Convênio nº 029/2005 (SIAFI nº 531006) não se confunde com o pedido do Estado do Piauí, que busca a sua exclusão definitiva do cadastro SIAFI/CAUC em relação ao supracitado convênio.
# Quanto ao mérito da ação, conforme já apontado pela União em suas alegações finais, esta Corte, no julgamento do RE 1.067.086, Tema 327 da sistemática da repercussão geral, de relatoria da Min. Rosa Weber, fixou a seguinte tese:
#
# “A inscrição de entes federados em cadastro de inadimplentes (ou outro que dê causa à negativa de realização de convênios, acordos, ajustes ou outros instrumentos congêneres que impliquem transferência voluntária de recursos), pressupõe o respeito aos princípios do contraditório, da ampla defesa e do devido processo legal, somente reconhecido: a) após o julgamento de tomada de contas especial ou procedimento análogo perante o Tribunal de Contas, nos casos de descumprimento parcial ou total de convênio, prestação de contas rejeitada, ou existência de débito decorrente de ressarcimento de recursos de natureza contratual (salvo os de conta não prestada); b) após a devida notificação do ente faltoso e o decurso do prazo nela previsto (conforme constante em lei, regras infralegais ou em contrato), independentemente de tomada de contas especial, nos casos de não prestação de contas, não fornecimento de informações, débito decorrente de conta não prestada, ou quaisquer outras hipóteses em que incabível a tomada de contas especial.” (Grifei)
#
# Por conseguinte, a par da discussão acerca da aplicabilidade do princípio da intranscendência subjetiva das penas financeiras ao presente caso, a alegada ofensa ao postulado do devido processo legal merece prosperar na medida em que não houve, efetivamente, no presente caso, o julgamento da tomada de contas especial anteriormente à inscrição da parte autora nos sistemas CAUC/SIAFI/CADIN e congêneres.
# A partir da análise dos documentos acostados, especialmente das Notas Técnicas nº 005/2019/Diad/CDTCE/CGPC/SPO/Secex/MDR e nº 00025/2019/CONJUR-MDR/CGU/AGU (eDOC 20), observa-se que entre os procedimentos adotados pela parte ré não consta a tomada de contas ou procedimento equivalente perante o Tribunal de Contas.
# Assim, à luz da tese fixada no RE 1.067.086, para o cumprimento dos princípios constitucionais do contraditório, da ampla defesa e do devido processo legal, impõe-se consignar que, em relação ao Convênio nº 29/2005 firmado entre o Ministério da Integração Nacional e a Secretaria de Infraestrutura Estadual, a inscrição do Estado do Piauí em cadastro de inadimplentes da União somente pode ser efetivada após o julgamento de tomada de contas especial ou procedimento análogo perante o Tribunal de Contas.
# Por fim, anoto que em processos da minha relatoria que tratam do mesmo tema, a União têm reconhecido expressamente a procedência do pedido autoral. Nesse sentido, vide decisão de homologação de reconhecimento da procedência do pedido formulado na ACO 3423.
#
# Ante o exposto, conheço da ação cível originária a que se dá parcial procedência, nos termos dos arts. 355, I, e 487, I, do CPC e art. 21, §1º, do RISTF, ratificando a liminar concedida previamente, com a finalidade de determinar a retirada da inscrição do Estado do Piauí no CAUC/SICONV/SIAFI ou qualquer outro cadastro restritivo referente ao Convênio nº 29/2005 firmado entre o Ministério da Integração Nacional e a Secretaria de Infraestrutura do Estado do Piauí, até a conclusão pelo Tribunal de Contas da União de Tomada de Contas Especial.
#
# Despesas processuais arcadas pela parte vencida.
# Tendo em vista o disposto no §8º do art. 85 do CPC, condeno a ré ao pagamento de R$ 500,00 (quinhentos reais) a título de honorários advocatícios sucumbenciais.
#
# Publique-se.
# Brasília, 23 de março de 2023.
#
# Ministro EDSON FACHIN
# Relator
# Documento assinado digitalmente
# <P> ACO 3573 ExecFazPub
# 'AUTOR(A/S)(ES) Empresa Brasileira de Pesquisa Agropecuaria '
# 'ADVOGADO(A/S) Katia Reale da Mota e Outro(a/s) |OAB 9542/PA'
# 'ADVOGADO(A/S) HORACIO EDUARDO GOMES VALE |OAB 18092/DF'
# 'RÉU(É)(S) Estado de Rondônia '
# 'ADVOGADO(A/S) Procurador-geral do Estado de Rondônia '
# DESPACHO
# 1. Em petição de e-doc. 15, a Empresa Brasileira de Pesquisa Agropecuária — EMBRAPA requer cumprimento de sentença para pagamento da quantia certa correspondente a R$ 10.521,07 (dez mil, quinhentos e vinte e um reais e sete centavos), relativa aos honorários advocatícios atualizados, que foram imputados ao vencido, no caso, o Estado de Rondônia.
#
# 2. Trânsito em julgado ocorrido em 30/06/2022 (e-doc. 14).
#
# 3. Intime-se o Estado de Rondônia para, caso queira, apresentar impugnação no prazo de 30 (trinta) dias, ou, desde já, efetivar o cumprimento da obrigação, na forma do art. 535, § 3º, inc. II, do CPC/2015.
#
# Publique-se.
#
# Intimem-se.
#
# Brasília, 26 de março de 2023.
#
#
# Ministro ANDRÉ MENDONÇA
# Relator
#
# <P> ACO 3576 ACO-AgR
# 'AGRAVANTE(S) Banco do Brasil Sa '
# 'ADVOGADO(A/S) Rafael Sganzerla Durand |OAB 211648/SP'
# 'AGRAVADO(A/S) Estado de Santa Catarina '
# 'ADVOGADO(A/S) Procurador-geral do Estado de Santa Catarina '
# 'INTERESSADO(A/S) União '
# 'PROCURADOR(ES) Advogado-geral da União '
#
# Decisão: (AgR) O Tribunal, por unanimidade, negou provimento aos agravos, nos termos do voto do Relator, com determinação de transladação de cópia do presente voto para a ACO 3578, apensada aos presentes autos. Plenário, Sessão Virtual de 10.3.2023 a 17.3.2023.
#
#
#
# <P> ACO 3576 ACO-AgR-segundo
# 'AGRAVANTE(S) Estado de Santa Catarina '
# 'PROCURADOR(ES) Procurador-geral do Estado de Santa Catarina '
# 'AGRAVADO(A/S) União '
# 'PROCURADOR(ES) Advogado-geral da União '
# 'AGRAVADO(A/S) Banco do Brasil Sa '
# 'ADVOGADO(A/S) Rafael Sganzerla Durand |OAB 211648/SP'
#
# Decisão: (AgR-segundo) O Tribunal, por unanimidade, negou provimento aos agravos, nos termos do voto do Relator, com determinação de transladação de cópia do presente voto para a ACO 3578, apensada aos presentes autos. Plenário, Sessão Virtual de 10.3.2023 a 17.3.2023.
#
#
#
#
# <P> ACO 3576 ACO-AgR-terceiro
# 'AGRAVANTE(S) União '
# 'PROCURADOR(ES) Advogado-geral da União '
# 'AGRAVADO(A/S) Estado de Santa Catarina '
# 'PROCURADOR(ES) Procurador-geral do Estado de Santa Catarina '
# 'INTERESSADO(A/S) Banco do Brasil Sa '
# 'ADVOGADO(A/S) Rafael Sganzerla Durand |OAB 211648/SP'
#
# Decisão: (AgR-terceiro) O Tribunal, por unanimidade, negou provimento aos agravos, nos termos do voto do Relator, com determinação de transladação de cópia do presente voto para a ACO 3578, apensada aos presentes autos. Plenário, Sessão Virtual de 10.3.2023 a 17.3.2023.
#
#
#
#
#
# <P> ACO 3580 ACO-AgR-ED
# 'EMBARGANTE(S) Empresa Brasileira de Pesquisa Agropecuaria '
# 'ADVOGADO(A/S) Andre Luiz Fuina Versiani e Outro(a/s) |OAB 09335/DF'
# 'ADVOGADO(A/S) RENATO FRANCISCO XAVIER |OAB 86398 /MG'
# 'ADVOGADO(A/S) HORACIO EDUARDO GOMES VALE |OAB 18092/DF'
# 'EMBARGADO(A/S) Distrito Federal '
# 'PROCURADOR(ES) Procurador-geral do Distrito Federal '
#
# Decisão: O Tribunal, por unanimidade, acolheu os embargos de declaração para, afastando as omissões apontadas, condenar o Distrito Federal ao pagamento de honorários advocatícios, fixados em R$ 3.000,00 (três mil reais), e aplicar a multa prevista no § 4º do art. 1.021 do Código de Processo Civil no percentual de 5%, nos termos do voto da Relatora. Plenário, Sessão Virtual de 10.3.2023 a 17.3.2023.
#
#
#
# <P> ACO 3631 Mérito
# 'AUTOR(A/S)(ES) Empresa Brasileira de Pesquisa Agropecuaria '
# 'ADVOGADO(A/S) Wernher Leonardo Moura Pedrosa e Outro(a/s) |OAB 7958/PI'
# 'ADVOGADO(A/S) ALBERTO DE MOURA MARQUES |OAB 57868/PR'
# 'ADVOGADO(A/S) ANA MARIA DE FARIAS PINHEIRO |OAB 4409/MS'
# 'RÉU(É)(S) Estado da Bahia '
# 'ADVOGADO(A/S) Procurador-geral do Estado da Bahia '
#
# <P> ACO 758 ExecFazPub
# 'AUTOR(A/S)(ES) Estado de Sergipe '
# 'PROCURADOR(ES) Procurador-geral do Estado de Sergipe '
# 'RÉU(É)(S) União '
# 'ADVOGADO(A/S) Advogado-geral da União '
# ('AMICUS CURIAE Associação Brasileira das Secretarias de Finanças das Capitais '
#  'Brasileiras - Abrasf ')
# 'ADVOGADO(A/S) Ricardo Almeida Ribeiro da Silva |OAB 81438/RJ'
# DESPACHO
#
# 1. Em petição (e-doc. 54), o Estado de Sergipe requer o cumprimento de acórdão do Tribunal Pleno julgado em 19/12/2016 (e-doc. 52) e transitado em julgado em 20/09/2017 (e-doc. 53, p. 4), para pagamento da quantia certa de R$ 114.271.656,00 (cento e quatorze milhões, duzentos e setenta e um mil e seiscentos e cinquenta e seis reais), correspondente à devolução dos valores descontados de forma inconstitucional no repasse do Fundo de Participação dos Estados (FPE), e de R$ 24.725,00 (vinte e quatro mil, setecentos e vinte e cinco reais), referente aos honorários advocatícios sucumbenciais, atualizados até julho de 2022 (conforme laudo e planilhas anexas, e-docs. 55 a 62).
#
# 2. Determinei, no despacho de e-doc. 69, a intimação da “União para, caso queira, apresentar impugnação no prazo de 30 (trinta) dias ou esclarecer se concorda com os valores apresentados na petição mencionada, ressaltando-se que o silêncio quanto aos valores apresentados será interpretado como concordância”.
#
# 3. Por meio da Petição nº 76.530/2022, a União apontou excesso de execução “relativo ao montante principal, no valor de R$ 60.074.243,85 (sessenta milhões, setenta e quatro mil, duzentos e quarenta e três reais e oitenta e cinco centavos), atualizado até julho de 2022, conforme Parecer Técnico nº 01016/2022/REPT/DISEP/PGU/AGU” e requereu seja o valor da condenação “fixado em R$ 54.222.137,15 (cinquenta e quatro milhões, duzentos e vinte e dois mil, cento e trinta e sete reais e quinze centavos), atualizado até julho de 2022, conforme Parecer Técnico nº 01016/2022/REPT/DISEP/PGU/AGU”. Argumentou, especificamente, que:
#
# “i) ‘a primeira inconsistência nos cálculos apresentados pelo autor decorre do fato de a correção monetária ter sido aplicada sobre todo o valor nominal nacional, e não apenas sobre a cota-parte devida ao Estado-autor’ e que ‘o que deve ser objeto de correção monetária são os valores nominais apurados mês a mês como devidos ao Estado-autor, conforme o seu coeficiente individual de participação previsto no Anexo da Lei Complementar nº 62, de 1989’;
# ii) ‘o Estado-autor não deduziu os repasses do FUNDEF/FUNDEB antes de apurar os valores que lhe são devidos’;
# iii) ‘o Estado-autor não observou, para o cálculo do valor devido a título de juros de mora, as diretrizes do Manual de Cálculos da Justiça Federal’;
# iv) ‘houve erro quanto à aplicação da taxa SELIC em decorrência da Emenda Constitucional nº 113/2021, conforme apontado pelo DCP/AGU’ e que ‘o autor adiciona 1% sobre a taxa acumulada de jul/22, que é de 6,07%’;
# v) ‘a União excluiu o cômputo de juros de mora entre o trânsito em julgado e o início do cumprimento de sentença. Isso porque, durante esse período, a mora decorreu exclusivamente da inércia do Estado-autor em promover a execução do título judicial’.
#
# 4. Intime-se a parte requerente para que se manifeste sobre a impugnação ao cumprimento de decisão, demonstrando sua concordância ou discordância em relação a cada um dos pontos acima destacados.
#
# 5. Em caso de discordância, deverá a requerente apontar, de modo claro e específico, os motivos pelos quais diverge em relação ao entendimento da União.
#
# 6. De antemão, esclareço, com base no princípio da cooperação (art. 6º do CPC) que esta Suprema Corte tem jurisprudência fixada no sentido da adoção do Manual de Cálculos da Justiça Federal como parâmetro a embasar os cálculos (ACO nº 502-AgR/SP, Rel. Min. Gilmar Mendes, Tribunal Pleno, j. 17/03/2016, p. 13/05/2016), de modo que se recomenda que eventual irresignação venha pautada nos critérios apontados no referido Manual.
#
# Publique-se.
#
# Intimem-se.
#
# Brasília, 26 de março de 2023.
#
#
# Ministro ANDRÉ MENDONÇA
# Relator
